# %%
import requests
url = 'https://opendata.cwa.gov.tw/api/v1/rest/datastore/F-C0032-001?Authorization=rdec-key-123-45678-011121314&format=JSON'

response = requests.get(url,verify=False)
if response.ok:
    print("下載成功")
    json_str:str = response.text
else:
    print("下載失敗")
# Out:
# 下載成功
# /home/vscode/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'opendata.cwa.gov.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
import json
jsonData = json.loads(json_str)
jsonData

# %%
#response實體方法json(),直接轉換為python的資料結構
jsonData1 = response.json()
jsonData1["records"]['datasetDescription']
jsonRecords = jsonData1["records"]["location"]
jsonRecords

# %%
weather_list:list[dict] = []
for item in jsonRecords:
    city_item:dict = {}
    city_item['城市'] = item['locationName']
    city_item['起始時間'] = item['weatherElement'][0]['time'][0]['startTime']
    city_item['結束時間'] = item['weatherElement'][0]['time'][1]['endTime']
    city_item['最低溫度'] = float(item['weatherElement'][2]['time'][0]['parameter']['parameterName'])
    city_item['最高溫度'] = float(item['weatherElement'][4]['time'][0]['parameter']['parameterName'])
    city_item['感覺'] = item['weatherElement'][3]['time'][0]['parameter']['parameterName']
    weather_list.append(city_item)
weather_list

# %%
import pandas as pd
dataFrame = pd.DataFrame(weather_list)
dataFrame
# Out:
#      城市                 起始時間                 結束時間  最低溫度  最高溫度       感覺
# 0   嘉義縣  2024-01-06 12:00:00  2024-01-07 06:00:00  19.0  24.0  稍有寒意至舒適
# 1   新北市  2024-01-06 12:00:00  2024-01-07 06:00:00  19.0  23.0  稍有寒意至舒適
# 2   嘉義市  2024-01-06 12:00:00  2024-01-07 06:00:00  19.0  25.0  稍有寒意至舒適
# 3   新竹縣  2024-01-06 12:00:00  2024-01-07 06:00:00  17.0  21.0  稍有寒意至舒適
# 4   新竹市  2024-01-06 12:00:00  2024-01-07 06:00:00  17.0  21.0  稍有寒意至舒適
# 5   臺北市  2024-01-06 12:00:00  2024-01-07 06:00:00  19.0  23.0  稍有寒意至舒適
# 6   臺南市  2024-01-06 12:00:00  2024-01-07 06:00:00  19.0  23.0  稍有寒意至舒適
# 7   宜蘭縣  2024-01-06 12:00:00  2024-01-07 06:00:00  19.0  23.0  稍有寒意至舒適
# 8   苗栗縣  2024-01-06 12:00:00  2024-01-07 06:00:00  17.0  21.0  稍有寒意至舒適
# 9   雲林縣  2024-01-06 12:00:00  2024-01-07 06:00:00  18.0  24.0  稍有寒意至舒適
# 10  花蓮縣  2024-01-06 12:00:00  2024-01-07 06:00:00  20.0  24.0  稍有寒意至舒適
# 11  臺中市  2024-01-06 12:00:00  2024-01-07 06:00:00  19.0  24.0  稍有寒意至舒適
# 12  臺東縣  2024-01-06 12:00:00  2024-01-07 06:00:00  21.0  24.0       舒適
# 13  桃園市  2024-01-06 12:00:00  2024-01-07 06:00:00  17.0  21.0  稍有寒意至舒適
# 14  南投縣  2024-01-06 12:00:00  2024-01-07 06:00:00  19.0  24.0  稍有寒意至舒適
# 15  高雄市  2024-01-06 12:00:00  2024-01-07 06:00:00  22.0  24.0       舒適
# 16  金門縣  2024-01-06 12:00:00  2024-01-07 06:00:00  16.0  22.0  稍有寒意至舒適
# 17  屏東縣  2024-01-06 12:00:00  2024-01-07 06:00:00  22.0  26.0       舒適
# 18  基隆市  2024-01-06 12:00:00  2024-01-07 06:00:00  18.0  20.0     稍有寒意
# 19  澎湖縣  2024-01-06 12:00:00  2024-01-07 06:00:00  18.0  21.0  稍有寒意至舒適
# 20  彰化縣  2024-01-06 12:00:00  2024-01-07 06:00:00  18.0  23.0  稍有寒意至舒適
# 21  連江縣  2024-01-06 12:00:00  2024-01-07 06:00:00  14.0  17.0  寒冷至稍有寒意

# %%
dataFrame.to_csv('天氣預測一天.csv')

# %%
dataFrame.to_excel('天氣預測一天.xlsx')
