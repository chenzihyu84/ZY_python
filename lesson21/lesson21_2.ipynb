# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({'key1':['a', 'a', 'b', 'b', 'a'],
                  'key2':['one', 'two', 'one', 'two', 'one'],
                  'data1': np.random.randn(5),
                  'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -1.974936 -0.012116
# 1    a  two -0.130233  0.432170
# 2    b  one -1.204038 -0.678897
# 3    b  two -0.154744 -0.199234
# 4    a  one -0.865386 -1.709807

# %%
df1 = df.set_index(keys=['key1','key2'])
df1
# Out:
#               data1     data2
# key1 key2
# a    one  -1.974936 -0.012116
#      two  -0.130233  0.432170
# b    one  -1.204038 -0.678897
#      two  -0.154744 -0.199234
# a    one  -0.865386 -1.709807

# %%
df1.columns.name = 'data'
df1
# Out:
# data          data1     data2
# key1 key2
# a    one  -1.974936 -0.012116
#      two  -0.130233  0.432170
# b    one  -1.204038 -0.678897
#      two  -0.154744 -0.199234
# a    one  -0.865386 -1.709807

# %%
df2 = df1.groupby(level=['key1','key2']).mean()
df2
# Out:
# data          data1     data2
# key1 key2
# a    one  -1.420161 -0.860962
#      two  -0.130233  0.432170
# b    one  -1.204038 -0.678897
#      two  -0.154744 -0.199234

# %%
df2.unstack(level='key1')
# Out:
# data     data1               data2
# key1         a         b         a         b
# key2
# one  -1.420161 -1.204038 -0.860962 -0.678897
# two  -0.130233 -0.154744  0.432170 -0.199234
