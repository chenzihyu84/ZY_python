# %%
import numpy as np
import pandas as pd

df = pd.read_csv('各鄉鎮市區人口密度.csv')
df.columns = df.iloc[0]
df1= df.drop(index=0)

# %%
df2 = df1.dropna()

# %%
df2.iloc[369]
df3 = df2.replace(to_replace="… ",value=0)
df3
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
# 369  106    東沙群島       0     2.38      0
# 370  106    南沙群島       0   0.5045      0
#
# [370 rows x 5 columns]

# %%
df3[['年底人口數','人口密度']] = df3[['年底人口數','人口密度']].astype(int)
df3['土地面積'] = df3['土地面積'].astype(float)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 370 entries, 1 to 370
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統計年     370 non-null    object
#  1   區域別     370 non-null    object
#  2   年底人口數   370 non-null    int64
#  3   土地面積    370 non-null    float64
#  4   人口密度    370 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 17.3+ KB

# %%
def split(v:str) -> str:
    if len(v)>4:
        return v[:3]
    else : 
        return v
df3['區域別'] = df3['區域別'].map(split)

# %%
df3.iloc[-20:]
# Out:
# 0    統計年   區域別   年底人口數     土地面積  人口密度
# 351  106   基隆市   47908  10.5238  4552
# 352  106   基隆市   82358  18.0250  4569
# 353  106   基隆市   52035  10.6706  4876
# 354  106   新竹市  212553  33.5768  6330
# 355  106   新竹市  150636  15.7267  9578
# 356  106   新竹市   77943  54.8491  1421
# 357  106   嘉義市  122103  30.1556  4049
# 358  106   嘉義市  147295  29.8700  4931
# 359  106   金門縣   43285  21.7130  1994
# 360  106   金門縣   29413  41.6960   705
# 361  106   金門縣   20535  41.1900   499
# 362  106   金門縣   30838  29.8540  1033
# 363  106   金門縣   12700  16.0030   794
# 364  106   金門縣     685   1.2000   571
# 365  106   連江縣    7544  10.4000   725
# 366  106   連江縣    2360   9.9000   238
# 367  106   連江縣    1624   4.7000   346
# 368  106   連江縣    1352   3.8000   356
# 369  106  東沙群島       0   2.3800     0
# 370  106  南沙群島       0   0.5045     0

# %%
df3.groupby(by='區域別')[['年底人口數','土地面積']].sum()
# Out:
# 0       年底人口數       土地面積
# 區域別
# 南投縣    501051  4106.4360
# 南沙群島        0     0.5045
# 嘉義市    269398    60.0256
# 嘉義縣    511182  1903.6367
# 基隆市    371458   132.7589
# 宜蘭縣    456607  2143.6251
# 屏東縣    829939  2775.6003
# 彰化縣   1282458  1074.3960
# 新北市   3986689  2052.5667
# 新竹市    441132   104.1526
# 新竹縣    552169  1427.5369
# 東沙群島        0     2.3800
# 桃園市   2188017  1220.9540
# 澎湖縣    104073   126.8641
# 臺中市   2787070  2214.8968
# 臺北市   2683257   271.7997
# 臺南市   1886522  2191.6531
# 臺東縣    219540  3515.2526
# 花蓮縣    329237  4628.5714
# 苗栗縣    553807  1820.3149
# 連江縣     12880    28.8000
# 金門縣    137456   151.6560
# 雲林縣    690373  1290.8326
# 高雄市   2776912  2951.8524

# %%
df3.groupby(by='區域別')[['年底人口數','土地面積']].sum()
